# %% [markdown]
# <a href="https://colab.research.google.com/github/anjalipaladi/Named-Entity-Recognition/blob/main/Set_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
matrix = [[1, 2], [3, 4], [5, 6]]
transpose = list(map(list, zip(*matrix)))
print(transpose)
# Out:
# [[1, 3, 5], [2, 4, 6]]

# %%
string = "hello world python"
reversed_string = " ".join(reversed(string.split()))
print(reversed_string)
# Out:
# python world hello
